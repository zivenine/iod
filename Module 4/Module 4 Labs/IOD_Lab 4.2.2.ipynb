# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.2: Feature Selection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %% [markdown]
# ### 5. Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# #### 5.1 Load Wine Data & Define Predictor and Target

# %%
## Load the wine quality dataset

# Load the wine dataset from csv
wine = pd.read_csv('../../DATA/winequality_merged.csv')

# define the target variable (dependent variable) as y
y = wine['quality']

# Take all columns except target as predictor columns
predictor_columns = [c for c in wine.columns if c != 'quality']
# Load the dataset as a pandas data frame
X = pd.DataFrame(wine, columns = predictor_columns)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# 1      9.8        5         1
# 2      9.8        5         1
# 3      9.8        6         1
# 4      9.4        5         1

# %%
## Create training and testing subsets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# #### 5.2 Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# #### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# #### Methods of the `LinearRegression` object to investigate
# - `fit()`
# - `fit.score()`
#
# #### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$
#
# #### Linear Regression [reference](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
## Flag intermediate output

show_steps = True   # for testing/debugging
# show_steps = False  # without showing steps

# %%
## Use Forward Feature Selection to pick a good model

# start with no predictors
included = []

# keep track of model and parameters
best = {'feature': '', 'r2': 0, 'a_r2': 0}

# create a model object to hold the modelling parameters
model = LinearRegression() # create a model for Linear Regression

# get the number of cases in the training data
n = X_train.shape[0]
p = X_train.shape[1]

while True:
    changed = False
    
    if show_steps:
        print('') 

    # list the features to be evaluated
    excluded = list(set(X.columns) - set(included))
    
    if show_steps:
        print('(Step) Excluded = %s' % ', '.join(excluded))  

    # for each remaining feature to be evaluated
    for new_column in excluded:
        
        if show_steps:
            print('(Step) Trying %s...' % new_column)
            print('(Step) - Features = %s' % ', '.join(included + [new_column]))

        # fit the model with the Training data
        fit = model.fit(X=X_train[included + [new_column]], y=y_train) # fit a model; consider which predictors should be included
        
        # calculate the score (R^2 for Regression)
        r2 = fit.score(X=X_train[included + [new_column]], y=y_train) # calculate the score
        
        # number of predictors in this model
        k = len(included) + 1
        
        # calculate the adjusted R^2
        adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1) # calculate the Adjusted R^2

        if show_steps:
            print('(Step) - Adjusted R^2: This = %.3f; Best = %.3f' % 
                  (adjusted_r2, best['a_r2']))

        # if model improves
        if adjusted_r2 > best['a_r2']:
            # record new parameters
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2}
            # flag that found a better model
            changed = True
            if show_steps:
                print('(Step) - New Best!   : Feature = %s; R^2 = %.3f; Adjusted R^2 = %.3f' % 
                      (best['feature'], best['r2'], best['a_r2']))
    # END for

    # if found a better model after testing all remaining features
    if changed:
        # update control details
        included.append(best['feature'])
        excluded = list(set(excluded) - set(best['feature']))
        print('Added feature %-4s with R^2 = %.3f and adjusted R^2 = %.3f' % 
              (best['feature'], best['r2'], best['a_r2']))
    else:
        # terminate if no better model
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = free sulfur dioxide, total sulfur dioxide, volatile acidity, chlorides, sulphates, residual sugar, citric acid, pH, red_wine, density, alcohol, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = free sulfur dioxide
# (Step) - Adjusted R^2: This = -0.000; Best = 0.000
# (Step) Trying total sulfur dioxide...
# (Step) - Features = total sulfur dioxide
# (Step) - Adjusted R^2: This = -0.000; Best = 0.000
# (Step) Trying volatile acidity...
# (Step) - Features = volatile acidity
# (Step) - Adjusted R^2: This = 0.067; Best = 0.000
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.069; Adjusted R^2 = 0.067
# (Step) Trying chlorides...
# (Step) - Features = chlorides
# (Step) - Adjusted R^2: This = 0.040; Best = 0.067
# (Step) Trying sulphates...
# (Step) - Features = sulphates
# (Step) - Adjusted R^2: This = -0.001; Best = 0.067
# (Step) Trying residual sugar...
# (Step) - Features = residual sugar
# (Step) - Adjusted R^2: This = -0.001; Best = 0.067
# (Step) Trying citric acid...
# (Step) - Features = citric acid
# (Step) - Adjusted R^2: This = 0.005; Best = 0.067
# (Step) Trying pH...
# (Step) - Features = pH
# (Step) - Adjusted R^2: This = -0.002; Best = 0.067
# (Step) Trying red_wine...
# (Step) - Features = red_wine
# (Step) - Adjusted R^2: This = 0.012; Best = 0.067
# (Step) Trying density...
# (Step) - Features = density
# (Step) - Adjusted R^2: This = 0.094; Best = 0.067
# (Step) - New Best!   : Feature = density; R^2 = 0.096; Adjusted R^2 = 0.094
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - Adjusted R^2: This = 0.199; Best = 0.094
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.201; Adjusted R^2 = 0.199
# (Step) Trying fixed acidity...
# (Step) - Features = fixed acidity
# (Step) - Adjusted R^2: This = 0.004; Best = 0.199
# Added feature alcohol with R^2 = 0.201 and adjusted R^2 = 0.199
#
# (Step) Excluded = free sulfur dioxide, total sulfur dioxide, volatile acidity, chlorides, sulphates, residual sugar, citric acid, pH, red_wine, density, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.215; Best = 0.199
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.217; Adjusted R^2 = 0.215
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.205; Best = 0.215
# (Step) Trying volatile acidity...
# (Step) - Features = alcohol, volatile acidity
# (Step) - Adjusted R^2: This = 0.259; Best = 0.215
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.261; Adjusted R^2 = 0.259
# (Step) Trying chlorides...
# (Step) - Features = alcohol, chlorides
# (Step) - Adjusted R^2: This = 0.208; Best = 0.259
# (Step) Trying sulphates...
# (Step) - Features = alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.200; Best = 0.259
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.216; Best = 0.259
# (Step) Trying citric acid...
# (Step) - Features = alcohol, citric acid
# (Step) - Adjusted R^2: This = 0.207; Best = 0.259
# (Step) Trying pH...
# (Step) - Features = alcohol, pH
# (Step) - Adjusted R^2: This = 0.200; Best = 0.259
# (Step) Trying red_wine...
# (Step) - Features = alcohol, red_wine
# (Step) - Adjusted R^2: This = 0.210; Best = 0.259
# (Step) Trying density...
# (Step) - Features = alcohol, density
# (Step) - Adjusted R^2: This = 0.199; Best = 0.259
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, fixed acidity
# (Step) - Adjusted R^2: This = 0.200; Best = 0.259
# Added feature volatile acidity with R^2 = 0.261 and adjusted R^2 = 0.259
#
# (Step) Excluded = free sulfur dioxide, total sulfur dioxide, chlorides, sulphates, residual sugar, citric acid, pH, red_wine, density, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.261; Best = 0.259
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.263; Adjusted R^2 = 0.261
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.261; Best = 0.261
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.259; Best = 0.261
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.268; Best = 0.261
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.269; Adjusted R^2 = 0.268
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.265; Best = 0.268
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.259; Best = 0.268
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.261; Best = 0.268
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.265; Best = 0.268
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, density
# (Step) - Adjusted R^2: This = 0.267; Best = 0.268
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.260; Best = 0.268
# Added feature sulphates with R^2 = 0.269 and adjusted R^2 = 0.268
#
# (Step) Excluded = free sulfur dioxide, total sulfur dioxide, chlorides, residual sugar, citric acid, pH, red_wine, density, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.270; Best = 0.268
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.272; Adjusted R^2 = 0.270
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.268; Best = 0.270
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, chlorides
# (Step) - Adjusted R^2: This = 0.269; Best = 0.270
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar
# (Step) - Adjusted R^2: This = 0.276; Best = 0.270
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.277; Adjusted R^2 = 0.276
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, citric acid
# (Step) - Adjusted R^2: This = 0.268; Best = 0.276
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, pH
# (Step) - Adjusted R^2: This = 0.268; Best = 0.276
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, red_wine
# (Step) - Adjusted R^2: This = 0.269; Best = 0.276
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, density
# (Step) - Adjusted R^2: This = 0.271; Best = 0.276
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, fixed acidity
# (Step) - Adjusted R^2: This = 0.268; Best = 0.276
# Added feature residual sugar with R^2 = 0.277 and adjusted R^2 = 0.276
#
# (Step) Excluded = free sulfur dioxide, total sulfur dioxide, chlorides, citric acid, pH, red_wine, density, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.276; Best = 0.276
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.278; Adjusted R^2 = 0.276
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.279; Best = 0.276
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.281; Adjusted R^2 = 0.279
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, chlorides
# (Step) - Adjusted R^2: This = 0.277; Best = 0.279
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, citric acid
# (Step) - Adjusted R^2: This = 0.277; Best = 0.279
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, pH
# (Step) - Adjusted R^2: This = 0.277; Best = 0.279
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine
# (Step) - Adjusted R^2: This = 0.280; Best = 0.279
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.282; Adjusted R^2 = 0.280
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, density
# (Step) - Adjusted R^2: This = 0.276; Best = 0.280
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, fixed acidity
# (Step) - Adjusted R^2: This = 0.276; Best = 0.280
# Added feature red_wine with R^2 = 0.282 and adjusted R^2 = 0.280
#
# (Step) Excluded = free sulfur dioxide, total sulfur dioxide, chlorides, citric acid, pH, density, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.282; Best = 0.280
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.284; Adjusted R^2 = 0.282
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.280; Best = 0.282
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, chlorides
# (Step) - Adjusted R^2: This = 0.282; Best = 0.282
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.284; Adjusted R^2 = 0.282
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.281; Best = 0.282
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, pH
# (Step) - Adjusted R^2: This = 0.281; Best = 0.282
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density
# (Step) - Adjusted R^2: This = 0.284; Best = 0.282
# (Step) - New Best!   : Feature = density; R^2 = 0.285; Adjusted R^2 = 0.284
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.281; Best = 0.284
# Added feature density with R^2 = 0.285 and adjusted R^2 = 0.284
#
# (Step) Excluded = free sulfur dioxide, total sulfur dioxide, chlorides, citric acid, pH, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.285; Best = 0.284
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.287; Adjusted R^2 = 0.285
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.284; Best = 0.285
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides
# (Step) - Adjusted R^2: This = 0.286; Best = 0.285
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.287; Adjusted R^2 = 0.286
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, citric acid
# (Step) - Adjusted R^2: This = 0.284; Best = 0.286
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, pH
# (Step) - Adjusted R^2: This = 0.285; Best = 0.286
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.284; Best = 0.286
# Added feature chlorides with R^2 = 0.287 and adjusted R^2 = 0.286
#
# (Step) Excluded = free sulfur dioxide, total sulfur dioxide, citric acid, pH, fixed acidity
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.287; Best = 0.286
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.289; Adjusted R^2 = 0.287
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.286; Best = 0.287
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, citric acid
# (Step) - Adjusted R^2: This = 0.286; Best = 0.287
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, pH
# (Step) - Adjusted R^2: This = 0.287; Best = 0.287
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, fixed acidity
# (Step) - Adjusted R^2: This = 0.286; Best = 0.287
# Added feature free sulfur dioxide with R^2 = 0.289 and adjusted R^2 = 0.287
#
# (Step) Excluded = total sulfur dioxide, citric acid, pH, fixed acidity
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.289; Best = 0.287
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.291; Adjusted R^2 = 0.289
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.287; Best = 0.289
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.288; Best = 0.289
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.288; Best = 0.289
# Added feature total sulfur dioxide with R^2 = 0.291 and adjusted R^2 = 0.289
#
# (Step) Excluded = citric acid, pH, fixed acidity
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.290; Best = 0.289
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.291; Adjusted R^2 = 0.290
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# (Step) - New Best!   : Feature = pH; R^2 = 0.292; Adjusted R^2 = 0.290
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# Added feature pH   with R^2 = 0.292 and adjusted R^2 = 0.290
#
# (Step) Excluded = citric acid, fixed acidity
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH, citric acid
# (Step) - Adjusted R^2: This = 0.290; Best = 0.290
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.292; Adjusted R^2 = 0.290
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity
# (Step) - Adjusted R^2: This = 0.294; Best = 0.290
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.295; Adjusted R^2 = 0.294
# Added feature fixed acidity with R^2 = 0.295 and adjusted R^2 = 0.294
#
# (Step) Excluded = citric acid
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity, citric acid
# (Step) - Adjusted R^2: This = 0.294; Best = 0.294
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.295; Adjusted R^2 = 0.294
# Added feature citric acid with R^2 = 0.295 and adjusted R^2 = 0.294
#
# (Step) Excluded =
#
# Resulting features:
# alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity, citric acid

# %%
final_model = model.fit(X_train[included], y_train)

# Get the coefficients from the model
coefficients = final_model.coef_

# Display the coefficients along with feature names
print("Intercept of the final model: " + str(final_model.intercept_))
print("\nCoefficients of the final model:\n")
for feature, coef in zip(included, coefficients):
    print(f"{feature}: {coef}")
# Out:
# Intercept of the final model: 102.34602133123104
#
# Coefficients of the final model:
#
# alcohol: 0.22194288215088548
# volatile acidity: -1.4484924463999755
# sulphates: 0.6932390636365305
# residual sugar: 0.061862468446554464
# red_wine: 0.34396920864858177
# density: -101.84337562150364
# chlorides: -0.9749623574214005
# free sulfur dioxide: 0.004096847607667352
# total sulfur dioxide: -0.00138012600702378
# pH: 0.511526740454089
# fixed acidity: 0.08484843807350434
# citric acid: -0.05385099258163724

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
