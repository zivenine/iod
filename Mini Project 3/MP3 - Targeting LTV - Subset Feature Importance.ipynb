# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, OneHotEncoder

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.base import is_regressor

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.feature_selection import RFE

from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)
pd.set_option('display.max_colwidth', 50)
seed = 42

# %%
# Load the raw data
df = pd.read_csv("Datasets\WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv\WA_Fn-UseC_-Marketing-Customer-Value-Analysis.csv")

# %% [markdown]
# ### Preprocessing

# %%
# Split the dataset by Number of Policies
policies = df['Number of Policies'].unique()

subsets = {}

for policy in policies:
    subsets[policy] = df[df['Number of Policies'] == policy]

# %%
# From the subsets dict we create individual datasets
df_1 = subsets[1]
df_2 = subsets[2]
df_3 = subsets[3]
df_4 = subsets[4]
df_5 = subsets[5]
df_6 = subsets[6]
df_7 = subsets[7]
df_8 = subsets[8]
df_9 = subsets[9]

# %%
# Create a list of all the subsets to work with
subset_list = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9]

# %%
# Set Customer as index for each subset and drop Effective To Date
def customer_as_index(data):
    for i, d in enumerate(data):
        temp_d = d.copy()
        temp_d.set_index("Customer", inplace=True)
        temp_d.drop(["Effective To Date", "Number of Policies"], axis=1, inplace=True)
        data[i] = temp_d
        
customer_as_index(subset_list)

# %%
df_1 = subset_list[0]
df_2 = subset_list[1]
df_3 = subset_list[2]
df_4 = subset_list[3]
df_5 = subset_list[4]
df_6 = subset_list[5]
df_7 = subset_list[6]
df_8 = subset_list[7]
df_9 = subset_list[8]

# %% [markdown]
# ### Get feature importance when predicting Customer Lifetime Value

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3251 entries, BU79786 to Y167826
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          3251 non-null   object
#  1   Customer Lifetime Value        3251 non-null   float64
#  2   Response                       3251 non-null   object
#  3   Coverage                       3251 non-null   object
#  4   Education                      3251 non-null   object
#  5   EmploymentStatus               3251 non-null   object
#  6   Gender                         3251 non-null   object
#  7   Income                         3251 non-null   int64
#  8   Location Code                  3251 non-null   object
#  9   Marital Status                 3251 non-null   object
#  10  Monthly Premium Auto           3251 non-null   int64
#  11  Months Since Last Claim        3251 non-null   int64
#  12  Months Since Policy Inception  3251 non-null   int64
#  13  Number of Open Complaints      3251 non-null   int64
#  14  Policy Type                    3251 non-null   object
#  15  Policy                         3251 non-null   object
#  16  Renew Offer Type               3251 non-null   object
#  17  Sales Channel                  3251 non-null   object
#  18  Total Claim Amount             3251 non-null   float64
#  19  Vehicle Class                  3251 non-null   object
#  20  Vehicle Size                   3251 non-null   object
# dtypes: float64(2), int64(5), object(14)
# memory usage: 558.8+ KB

# %%
# Define which columns are numerical and which are categorical
num_features = ['Income', 'Monthly Premium Auto',
       'Months Since Last Claim', 'Months Since Policy Inception',
       'Number of Open Complaints', 'Total Claim Amount']
cat_features = ['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus',
       'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy',
       'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']

# Define the ColumnTransformer to apply different preprocessing to different columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
    ])

# Define the RFE with Linear Regression as the estimator
estimator = [LinearRegression(), 
             RandomForestRegressor(n_estimators=100, criterion="squared_error", max_depth=20), 
             XGBRegressor()]


def subsets_pipeline(data):
    set_name = []
    model_name = []
    model_rmse = []
    model_mape = []
    model_features = []
    for idx, d in enumerate(data):
        X = d.drop(["Customer Lifetime Value"], axis=1)
        y = d["Customer Lifetime Value"]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
        
        for est in estimator:
            selector = RFE(est, n_features_to_select=20, step=1)
            pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('selector', selector),
                           ('model', est)])
            pipeline.fit(X_train, y_train)
            y_pred = pipeline.predict(X_test)
            rmse = np.mean(mean_squared_error(y_test, y_pred))
            mape = mean_absolute_percentage_error(y_test, y_pred)
            set_name.append(f"Dataset {idx + 1}")
            model_name.append(est)
            model_rmse.append(rmse)
            model_mape.append(mape)
            if isinstance(est, LinearRegression):
                model_features.append(pipeline.named_steps['model'].coef_)
            elif hasattr(est, 'feature_importances_') and is_regressor(est):
                model_features.append(pipeline.named_steps['model'].feature_importances_)
            else:
                model_features.append(None)
    table = pd.DataFrame({
        'Subset': set_name,
        'Model': model_name,
        'RMSE': model_rmse,
        'MAPE': model_mape,
        'Features': model_features
    })
    return table

# %%
# data_sets = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9]
# subsets_pipeline(data_sets)

# %% [markdown]
# Print feature importance table for each model for each subset.

# %%
# Define which columns are numerical and which are categorical
num_features = ['Income', 'Monthly Premium Auto',
       'Months Since Last Claim', 'Months Since Policy Inception',
       'Number of Open Complaints', 'Total Claim Amount']
cat_features = ['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus',
       'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy',
       'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']

# Define the ColumnTransformer to apply different preprocessing to different columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
    ])

# Define the RFE with Linear Regression as the estimator
estimator = [LinearRegression(), 
             RandomForestRegressor(n_estimators=100, criterion="squared_error", max_depth=20), 
             XGBRegressor()]


def subsets_pipeline(data):
    set_name = []
    model_name = []
    model_rmse = []
    model_mape = []
    model_features = []
    for idx, d in enumerate(data):
        X = d.drop(["Customer Lifetime Value"], axis=1)
        y = d["Customer Lifetime Value"]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
        
        for est in estimator:
            selector = RFE(est, n_features_to_select=5, step=1)
            pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('selector', selector),
                           ('model', est)])
            pipeline.fit(X_train, y_train)
            y_pred = pipeline.predict(X_test)
            rmse = np.mean(mean_squared_error(y_test, y_pred))
            mape = mean_absolute_percentage_error(y_test, y_pred)
            
            set_name = f"Dataset {idx + 1}"
            model_name = est
            model_rmse = rmse
            model_mape = mape
            print(f"\n\n{set_name} - {model_name} - {rmse} - {mape}")
            
            feature_names = pipeline.named_steps['preprocessor'].get_feature_names_out()
            feature_importances = pipeline.named_steps['selector'].ranking_
            
            top_features = sorted(zip(feature_names, feature_importances), key=lambda x: x[1], reverse=False)[:10]
            
            print(top_features)

# %%
data_sets = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9]
# subsets_pipeline(data_sets)

# %% [markdown]
# We can see that Income and Monthly Premium are quite consistently the most important features.
#
# Let's create models to predict Income and Monthly Premium, then get feature importance from those models.

# %% [markdown]
# ### Feature importance for predicting Income

# %% [markdown]
# Prepare the subset data to get feature importance for predicting Income

# %%
# Remove CLV from each subset
inc_sets = {}
for idx, d in enumerate(data_sets):
    inc_sets[f"inc_set_{idx + 1}"] = d.drop(["Customer Lifetime Value"], axis=1)

# %%
# Create new subsets from each of the dictionary values
inc_subset_list = list(inc_sets.values())

# %%
# Define which columns are numerical and which are categorical
num_features = ['Monthly Premium Auto',
       'Months Since Last Claim', 'Months Since Policy Inception',
       'Number of Open Complaints', 'Total Claim Amount']
cat_features = ['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus',
       'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy',
       'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']

# Define the ColumnTransformer to apply different preprocessing to different columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
    ])

# Define the RFE with Linear Regression as the estimator
estimator = [LinearRegression(), 
             RandomForestRegressor(n_estimators=100, criterion="squared_error", max_depth=20), 
             XGBRegressor()]


def inc_pipeline(data):
    inc_dict = {}
    set_name = []
    for idx, d in enumerate(data):
        X = d.drop(["Income"], axis=1)
        y = d["Income"]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
        
        for est in estimator:
            selector = RFE(est, n_features_to_select=20, step=1)
            pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('selector', selector),
                           ('model', est)])
            pipeline.fit(X_train, y_train)
            y_pred = pipeline.predict(X_test)
            # Get the evaluation metrics
            rmse = np.mean(mean_squared_error(y_test, y_pred))
            mape = mean_absolute_percentage_error(y_test, y_pred)
            # Get the feature names
            feature_names = pipeline.named_steps['preprocessor'].get_feature_names_out()
            feature_importances = pipeline.named_steps['selector'].ranking_
            top_features = sorted(zip(feature_names, feature_importances), key=lambda x: x[1], reverse=False)[:10]
            
            inc_dict[f"inc_set {idx + 1} - {est} - {rmse} - {mape}"] = top_features
            
    table = pd.DataFrame(inc_dict)
    return table

# %%
inc_pipeline(inc_subset_list)
# Out:
#   inc_set 1 - LinearRegression() - 860334351.0983104 - 4.091277440656694e+19  \
# 0               (cat__Policy Type_Corporate Auto, 1)
# 1                (cat__Policy Type_Personal Auto, 1)
# 2                        (cat__Policy_Special L1, 1)
# 3                        (cat__Policy_Special L2, 1)
# 4                        (cat__Policy_Special L3, 1)
# 5                  (cat__Renew Offer Type_Offer1, 1)
# 6                  (cat__Renew Offer Type_Offer2, 1)
# 7                  (cat__Renew Offer Type_Offer3, 1)
# 8                  (cat__Renew Offer Type_Offer4, 1)
# 9                (cat__Sales Channel_Call Center, 1)
#
#   inc_set 1 - RandomForestRegressor(max_depth=20) - 261152648.17097747 - 0.2508736034713302  \
# 0                     (num__Monthly Premium Auto, 1)
# 1                  (num__Months Since Last Claim, 1)
# 2            (num__Months Since Policy Inception, 1)
# 3                (num__Number of Open Complaints, 1)
# 4                       (num__Total Claim Amount, 1)
# 5                             (cat__State_Oregon, 1)
# 6                             (cat__Response_Yes, 1)
# 7                       (cat__Education_Bachelor, 1)
# 8           (cat__Education_High School or Below, 1)
# 9                (cat__EmploymentStatus_Employed, 1)
#
#   inc_set 1 - XGBRegressor(base_score=None, booster=None, callbacks=None,\n             colsample_bylevel=None, colsample_bynode=None,\n             colsample_bytree=None, device=None, early_stopping_rounds=None,\n             enable_categorical=False, eval_metric=None, feature_types=None,\n             gamma=None, grow_policy=None, importance_type=None,\n             interaction_constraints=None, learning_rate=None, max_bin=None,\n             max_cat_threshold=None, max_cat_to_onehot=None,\n             max_delta_step=None, max_depth=None, max_leaves=None,\n             min_child_weight=None, missing=nan, monotone_constraints=None,\n             multi_strategy=None, n_estimators=None, n_jobs=None,\n             num_parallel_tree=None, random_state=None, ...) - 319653425.3421351 - 3.616122175395065e+18  \
# 0            (num__Months Since Policy Inception, 1)
# 1                       (num__Total Claim Amount, 1)
# 2                              (cat__Response_No, 1)
# 3                           (cat__Coverage_Basic, 1)
# 4                        (cat__Coverage_Extended, 1)
# 5                         (cat__Coverage_Premium, 1)
# 6                         (cat__Education_Doctor, 1)
# 7           (cat__Education_High School or Below, 1)
# 8                         (cat__Education_Master, 1)
# 9                (cat__EmploymentStatus_Employed, 1)
#
#   inc_set 2 - LinearRegression() - 876773028.8496732 - 4.102541815848286e+19  \
# 0                  (cat__Marital Status_Divorced, 1)
# 1                   (cat__Marital Status_Married, 1)
# 2                    (cat__Marital Status_Single, 1)
# 3               (cat__Policy Type_Corporate Auto, 1)
# 4                (cat__Policy Type_Personal Auto, 1)
# 5                 (cat__Policy Type_Special Auto, 1)
# 6                        (cat__Policy_Special L1, 1)
# 7                        (cat__Policy_Special L2, 1)
# 8                        (cat__Policy_Special L3, 1)
# 9                  (cat__Renew Offer Type_Offer1, 1)
#
#   inc_set 2 - RandomForestRegressor(max_depth=20) - 266976707.26073793 - 0.23930977957029187  \
# 0                     (num__Monthly Premium Auto, 1)
# 1                  (num__Months Since Last Claim, 1)
# 2            (num__Months Since Policy Inception, 1)
# 3                (num__Number of Open Complaints, 1)
# 4                       (num__Total Claim Amount, 1)
# 5                         (cat__State_California, 1)
# 6                              (cat__Response_No, 1)
# 7                       (cat__Education_Bachelor, 1)
# 8           (cat__Education_High School or Below, 1)
# 9                (cat__EmploymentStatus_Employed, 1)
#
#   inc_set 2 - XGBRegressor(base_score=None, booster=None, callbacks=None,\n             colsample_bylevel=None, colsample_bynode=None,\n             colsample_bytree=None, device=None, early_stopping_rounds=None,\n             enable_categorical=False, eval_metric=None, feature_types=None,\n             gamma=None, grow_policy=None, importance_type=None,\n             interaction_constraints=None, learning_rate=None, max_bin=None,\n             max_cat_threshold=None, max_cat_to_onehot=None,\n             max_delta_step=None, max_depth=None, max_leaves=None,\n             min_child_weight=None, missing=nan, monotone_constraints=None,\n             multi_strategy=None, n_estimators=None, n_jobs=None,\n             num_parallel_tree=None, random_state=None, ...) - 294819764.83577335 - 2.9093546733407867e+18  \
# 0            (num__Months Since Policy Inception, 1)
# 1                       (num__Total Claim Amount, 1)
# 2                         (cat__State_Washington, 1)
# 3                              (cat__Response_No, 1)
# 4                           (cat__Coverage_Basic, 1)
# 5                        (cat__Coverage_Extended, 1)
# 6                         (cat__Education_Master, 1)
# 7                (cat__EmploymentStatus_Employed, 1)
# 8              (cat__EmploymentStatus_Unemployed, 1)
# 9                                 (cat__Gender_F, 1)
#
#   inc_set 3 - LinearRegression() - 734980688.4145299 - 3.026665300341821e+19  \
# 0                      (cat__Location Code_Rural, 1)
# 1                   (cat__Location Code_Suburban, 1)
# 2                      (cat__Location Code_Urban, 1)
# 3                  (cat__Marital Status_Divorced, 1)
# 4                   (cat__Marital Status_Married, 1)
# 5                    (cat__Marital Status_Single, 1)
# 6                (cat__Policy Type_Personal Auto, 1)
# 7                      (cat__Policy_Corporate L2, 1)
# 8                      (cat__Policy_Corporate L3, 1)
# 9                  (cat__Renew Offer Type_Offer1, 1)
#
#   inc_set 3 - RandomForestRegressor(max_depth=20) - 309746337.06098664 - 0.2714710675314498  \
# 0                     (num__Monthly Premium Auto, 1)
# 1                  (num__Months Since Last Claim, 1)
# 2            (num__Months Since Policy Inception, 1)
# 3                (num__Number of Open Complaints, 1)
# 4                       (num__Total Claim Amount, 1)
# 5                         (cat__State_California, 1)
# 6                             (cat__State_Oregon, 1)
# 7                       (cat__Education_Bachelor, 1)
# 8                        (cat__Education_College, 1)
# 9                (cat__EmploymentStatus_Employed, 1)
#
#   inc_set 3 - XGBRegressor(base_score=None, booster=None, callbacks=None,\n             colsample_bylevel=None, colsample_bynode=None,\n             colsample_bytree=None, device=None, early_stopping_rounds=None,\n             enable_categorical=False, eval_metric=None, feature_types=None,\n             gamma=None, grow_policy=None, importance_type=None,\n             interaction_constraints=None, learning_rate=None, max_bin=None,\n             max_cat_threshold=None, max_cat_to_onehot=None,\n             max_delta_step=None, max_depth=None, max_leaves=None,\n             min_child_weight=None, missing=nan, monotone_constraints=None,\n             multi_strategy=None, n_estimators=None, n_jobs=None,\n             num_parallel_tree=None, random_state=None, ...) - 386086059.1945321 - 2.9915185313744553e+18  \
# 0                       (num__Total Claim Amount, 1)
# 1                            (cat__State_Arizona, 1)
# 2                              (cat__Response_No, 1)
# 3                (cat__EmploymentStatus_Employed, 1)
# 4              (cat__EmploymentStatus_Unemployed, 1)
# 5                                 (cat__Gender_F, 1)
# 6                   (cat__Location Code_Suburban, 1)
# 7                  (cat__Marital Status_Divorced, 1)
# 8                   (cat__Marital Status_Married, 1)
# 9                      (cat__Policy_Corporate L3, 1)
#
#   inc_set 4 - LinearRegression() - 242918122.6707317 - 6.692568734059258e+18  \
# 0                              (cat__Response_No, 1)
# 1                             (cat__Response_Yes, 1)
# 2                           (cat__Coverage_Basic, 1)
# 3                        (cat__Coverage_Extended, 1)
# 4                         (cat__Coverage_Premium, 1)
# 5                       (cat__Education_Bachelor, 1)
# 6                        (cat__Education_College, 1)
# 7                         (cat__Education_Doctor, 1)
# 8           (cat__Education_High School or Below, 1)
# 9                         (cat__Education_Master, 1)
#
#   inc_set 4 - RandomForestRegressor(max_depth=20) - 189222141.8600512 - 0.19474464678252254  \
# 0                     (num__Monthly Premium Auto, 1)
# 1                  (num__Months Since Last Claim, 1)
# 2            (num__Months Since Policy Inception, 1)
# 3                (num__Number of Open Complaints, 1)
# 4                       (num__Total Claim Amount, 1)
# 5                         (cat__State_California, 1)
# 6                       (cat__Education_Bachelor, 1)
# 7           (cat__Education_High School or Below, 1)
# 8                (cat__EmploymentStatus_Employed, 1)
# 9              (cat__EmploymentStatus_Unemployed, 1)
#
#   inc_set 4 - XGBRegressor(base_score=None, booster=None, callbacks=None,\n             colsample_bylevel=None, colsample_bynode=None,\n             colsample_bytree=None, device=None, early_stopping_rounds=None,\n             enable_categorical=False, eval_metric=None, feature_types=None,\n             gamma=None, grow_policy=None, importance_type=None,\n             interaction_constraints=None, learning_rate=None, max_bin=None,\n             max_cat_threshold=None, max_cat_to_onehot=None,\n             max_delta_step=None, max_depth=None, max_leaves=None,\n             min_child_weight=None, missing=nan, monotone_constraints=None,\n             multi_strategy=None, n_estimators=None, n_jobs=None,\n             num_parallel_tree=None, random_state=None, ...) - 237299358.20869097 - 2.7003033763261363e+18  \
# 0                     (num__Monthly Premium Auto, 1)
# 1                  (num__Months Since Last Claim, 1)
# 2                       (num__Total Claim Amount, 1)
# 3                         (cat__State_California, 1)
# 4                              (cat__Response_No, 1)
# 5                         (cat__Coverage_Premium, 1)
# 6                        (cat__Education_College, 1)
# 7           (cat__Education_High School or Below, 1)
# 8                (cat__EmploymentStatus_Employed, 1)
# 9              (cat__EmploymentStatus_Unemployed, 1)
#
#   inc_set 5 - LinearRegression() - 428532123.0731707 - 4.256670555118572e+18  \
# 0                           (cat__Coverage_Basic, 1)
# 1                        (cat__Coverage_Extended, 1)
# 2                         (cat__Coverage_Premium, 1)
# 3                (cat__EmploymentStatus_Disabled, 1)
# 4                (cat__EmploymentStatus_Employed, 1)
# 5           (cat__EmploymentStatus_Medical Leave, 1)
# 6                 (cat__EmploymentStatus_Retired, 1)
# 7              (cat__EmploymentStatus_Unemployed, 1)
# 8                      (cat__Location Code_Rural, 1)
# 9                   (cat__Location Code_Suburban, 1)
#
#   inc_set 5 - RandomForestRegressor(max_depth=20) - 400272376.0780241 - 0.34910121712111036  \
# 0                     (num__Monthly Premium Auto, 1)
# 1                  (num__Months Since Last Claim, 1)
# 2            (num__Months Since Policy Inception, 1)
# 3                (num__Number of Open Complaints, 1)
# 4                       (num__Total Claim Amount, 1)
# 5                         (cat__State_California, 1)
# 6                        (cat__Coverage_Extended, 1)
# 7                        (cat__Education_College, 1)
# 8                (cat__EmploymentStatus_Employed, 1)
# 9              (cat__EmploymentStatus_Unemployed, 1)
#
#   inc_set 5 - XGBRegressor(base_score=None, booster=None, callbacks=None,\n             colsample_bylevel=None, colsample_bynode=None,\n             colsample_bytree=None, device=None, early_stopping_rounds=None,\n             enable_categorical=False, eval_metric=None, feature_types=None,\n             gamma=None, grow_policy=None, importance_type=None,\n             interaction_constraints=None, learning_rate=None, max_bin=None,\n             max_cat_threshold=None, max_cat_to_onehot=None,\n             max_delta_step=None, max_depth=None, max_leaves=None,\n             min_child_weight=None, missing=nan, monotone_constraints=None,\n             multi_strategy=None, n_estimators=None, n_jobs=None,\n             num_parallel_tree=None, random_state=None, ...) - 446751609.1249721 - 1.1400654545283014e+18  \
# 0            (num__Months Since Policy Inception, 1)
# ...
# 3                            (cat__State_Arizona, 1)
# 4                         (cat__State_California, 1)
# 5                              (cat__Response_No, 1)
# 6                       (cat__Education_Bachelor, 1)
# 7           (cat__Education_High School or Below, 1)
# 8                (cat__EmploymentStatus_Employed, 1)
# 9              (cat__EmploymentStatus_Unemployed, 1)
#
#   inc_set 9 - LinearRegression() - 642903378.3571428 - 2.8905389151214522e+19  \
# 0                            (cat__State_Arizona, 1)
# 1                         (cat__State_California, 1)
# 2                             (cat__State_Nevada, 1)
# 3                             (cat__State_Oregon, 1)
# 4                         (cat__State_Washington, 1)
# 5                              (cat__Response_No, 1)
# 6                             (cat__Response_Yes, 1)
# 7                       (cat__Education_Bachelor, 1)
# 8                        (cat__Education_College, 1)
# 9                         (cat__Education_Doctor, 1)
#
#   inc_set 9 - RandomForestRegressor(max_depth=20) - 260461539.79780832 - 0.254388843236782  \
# 0                     (num__Monthly Premium Auto, 1)
# 1                  (num__Months Since Last Claim, 1)
# 2            (num__Months Since Policy Inception, 1)
# 3                (num__Number of Open Complaints, 1)
# 4                       (num__Total Claim Amount, 1)
# 5                             (cat__State_Nevada, 1)
# 6                       (cat__Education_Bachelor, 1)
# 7                        (cat__Education_College, 1)
# 8                (cat__EmploymentStatus_Employed, 1)
# 9              (cat__EmploymentStatus_Unemployed, 1)
#
#   inc_set 9 - XGBRegressor(base_score=None, booster=None, callbacks=None,\n             colsample_bylevel=None, colsample_bynode=None,\n             colsample_bytree=None, device=None, early_stopping_rounds=None,\n             enable_categorical=False, eval_metric=None, feature_types=None,\n             gamma=None, grow_policy=None, importance_type=None,\n             interaction_constraints=None, learning_rate=None, max_bin=None,\n             max_cat_threshold=None, max_cat_to_onehot=None,\n             max_delta_step=None, max_depth=None, max_leaves=None,\n             min_child_weight=None, missing=nan, monotone_constraints=None,\n             multi_strategy=None, n_estimators=None, n_jobs=None,\n             num_parallel_tree=None, random_state=None, ...) - 296023694.35768574 - 2.01480146752178e+18
# 0                  (num__Months Since Last Claim, 1)
# 1            (num__Months Since Policy Inception, 1)
# 2                (num__Number of Open Complaints, 1)
# 3                       (num__Total Claim Amount, 1)
# 4                            (cat__State_Arizona, 1)
# 5                             (cat__State_Nevada, 1)
# 6                              (cat__Response_No, 1)
# 7           (cat__Education_High School or Below, 1)
# 8                (cat__EmploymentStatus_Employed, 1)
# 9              (cat__EmploymentStatus_Unemployed, 1)

# %% [markdown]
# We can see that Monthly Premium Auto is the most important feature in predicting Income.

# %% [markdown]
# ### Feature importance in predicting Monthly Premium

# %%
# Remove CLV and Income from each subset
mpa_sets = {}
for idx, d in enumerate(data_sets):
    mpa_sets[f"inc_set_{idx + 1}"] = d.drop(["Customer Lifetime Value", "Income"], axis=1)

# %%
# Create new subsets from each of the dictionary values
mpa_subset_list = list(mpa_sets.values())

# %%
# Define which columns are numerical and which are categorical
num_features = ['Months Since Last Claim', 'Months Since Policy Inception',
       'Number of Open Complaints', 'Total Claim Amount']
cat_features = ['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus',
       'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy',
       'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']

# Define the ColumnTransformer to apply different preprocessing to different columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
    ])

# Define the RFE with Linear Regression as the estimator
estimator = [LinearRegression(), 
             RandomForestRegressor(n_estimators=100, criterion="squared_error", max_depth=20), 
             XGBRegressor()]


def mpa_pipeline(data):
    mpa_dict = {}
    set_name = []
    for idx, d in enumerate(data):
        X = d.drop(["Monthly Premium Auto"], axis=1)
        y = d["Monthly Premium Auto"]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
        
        for est in estimator:
            selector = RFE(est, n_features_to_select=20, step=1)
            pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('selector', selector),
                           ('model', est)])
            pipeline.fit(X_train, y_train)
            y_pred = pipeline.predict(X_test)
            # Get the evaluation metrics
            rmse = np.mean(mean_squared_error(y_test, y_pred))
            mape = mean_absolute_percentage_error(y_test, y_pred)
            # Get the feature names
            feature_names = pipeline.named_steps['preprocessor'].get_feature_names_out()
            feature_importances = pipeline.named_steps['selector'].ranking_
            top_features = sorted(zip(feature_names, feature_importances), key=lambda x: x[1], reverse=False)[:50]
            
            mpa_dict[f"inc_set {idx + 1} - {est} - {rmse} - {mape}"] = top_features
            
    table = pd.DataFrame(mpa_dict)
    return table

# %%
mpa_imp_feats = mpa_pipeline(mpa_subset_list)

# %%
mpa_imp_feats
# Out:
#    inc_set 1 - LinearRegression() - 49.44839740729651 - 0.05325745219950998  \
# 0                        (num__Total Claim Amount, 1)
# 1                            (cat__Coverage_Basic, 1)
# 2                         (cat__Coverage_Extended, 1)
# 3                          (cat__Coverage_Premium, 1)
# 4                          (cat__Education_Doctor, 1)
# 5                 (cat__EmploymentStatus_Disabled, 1)
# 6               (cat__EmploymentStatus_Unemployed, 1)
# 7                       (cat__Location Code_Rural, 1)
# 8                    (cat__Location Code_Suburban, 1)
# 9                       (cat__Policy_Corporate L1, 1)
# 10                        (cat__Policy_Special L1, 1)
# 11                        (cat__Policy_Special L2, 1)
# 12                        (cat__Policy_Special L3, 1)
# 13                  (cat__Renew Offer Type_Offer3, 1)
# 14              (cat__Vehicle Class_Four-Door Car, 1)
# 15                 (cat__Vehicle Class_Luxury Car, 1)
# 16                 (cat__Vehicle Class_Luxury SUV, 1)
# 17                        (cat__Vehicle Class_SUV, 1)
# 18                 (cat__Vehicle Class_Sports Car, 1)
# 19               (cat__Vehicle Class_Two-Door Car, 1)
# 20                    (cat__Marital Status_Single, 2)
# 21                         (cat__State_Washington, 3)
# 22                         (cat__State_California, 4)
# 23                                 (cat__Gender_F, 5)
# 24                        (cat__Sales Channel_Web, 6)
# 25                       (cat__Vehicle Size_Large, 7)
# 26                       (cat__Policy_Personal L2, 8)
# 27                (cat__EmploymentStatus_Employed, 9)
# 28          (cat__EmploymentStatus_Medical Leave, 10)
# 29                       (cat__Education_College, 11)
# 30          (cat__Education_High School or Below, 12)
# 31                     (cat__Location Code_Urban, 13)
# 32              (cat__Policy Type_Corporate Auto, 14)
# 33                     (cat__Policy_Corporate L3, 15)
# 34                                (cat__Gender_M, 16)
# 35                     (cat__Sales Channel_Agent, 17)
# 36                           (cat__State_Arizona, 18)
# 37                            (cat__State_Nevada, 19)
# 38                        (cat__Education_Master, 20)
# 39                      (cat__Policy_Personal L3, 21)
# 40                    (cat__Vehicle Size_Medsize, 22)
# 41                            (cat__Response_Yes, 23)
# 42                    (cat__Sales Channel_Branch, 24)
# 43               (cat__Policy Type_Personal Auto, 25)
# 44                (cat__Policy Type_Special Auto, 26)
# 45                 (cat__Marital Status_Divorced, 27)
# 46                  (cat__Marital Status_Married, 28)
# 47                 (num__Months Since Last Claim, 29)
# 48                            (cat__State_Oregon, 30)
# 49                 (cat__Renew Offer Type_Offer1, 31)
#
#    inc_set 1 - RandomForestRegressor(max_depth=20) - 35.72332772040385 - 0.03344455838964523  \
# 0                   (num__Months Since Last Claim, 1)
# 1             (num__Months Since Policy Inception, 1)
# 2                        (num__Total Claim Amount, 1)
# 3                               (cat__Response_No, 1)
# 4                            (cat__Coverage_Basic, 1)
# 5                         (cat__Coverage_Extended, 1)
# 6                          (cat__Coverage_Premium, 1)
# 7                 (cat__EmploymentStatus_Employed, 1)
# 8               (cat__EmploymentStatus_Unemployed, 1)
# 9                                  (cat__Gender_M, 1)
# 10                      (cat__Location Code_Rural, 1)
# 11                   (cat__Location Code_Suburban, 1)
# 12                   (cat__Marital Status_Married, 1)
# 13              (cat__Vehicle Class_Four-Door Car, 1)
# 14                 (cat__Vehicle Class_Luxury Car, 1)
# 15                 (cat__Vehicle Class_Luxury SUV, 1)
# 16                        (cat__Vehicle Class_SUV, 1)
# 17                 (cat__Vehicle Class_Sports Car, 1)
# 18               (cat__Vehicle Class_Two-Door Car, 1)
# 19                     (cat__Vehicle Size_Medsize, 1)
# 20                (num__Number of Open Complaints, 2)
# 21                     (cat__Sales Channel_Branch, 3)
# 22                      (cat__Sales Channel_Agent, 4)
# 23                         (cat__Education_Master, 5)
# 24                        (cat__Education_College, 6)
# 25                (cat__Sales Channel_Call Center, 7)
# 26                  (cat__Renew Offer Type_Offer1, 8)
# 27                       (cat__Policy_Personal L2, 9)
# 28                      (cat__Education_Bachelor, 10)
# 29                            (cat__Response_Yes, 11)
# 30                 (cat__Renew Offer Type_Offer2, 12)
# 31          (cat__Education_High School or Below, 13)
# 32                        (cat__State_California, 14)
# 33                   (cat__Marital Status_Single, 15)
# 34                 (cat__Renew Offer Type_Offer4, 16)
# 35                 (cat__Marital Status_Divorced, 17)
# 36                 (cat__Renew Offer Type_Offer3, 18)
# 37                      (cat__Vehicle Size_Small, 19)
# 38                                (cat__Gender_F, 20)
# 39                      (cat__Policy_Personal L3, 21)
# 40                     (cat__Location Code_Urban, 22)
# 41                            (cat__State_Oregon, 23)
# 42                           (cat__State_Arizona, 24)
# 43               (cat__Policy Type_Personal Auto, 25)
# 44                       (cat__Sales Channel_Web, 26)
# 45                     (cat__Policy_Corporate L2, 27)
# 46                      (cat__Policy_Personal L1, 28)
# 47                        (cat__State_Washington, 29)
# 48                        (cat__Education_Doctor, 30)
# 49                     (cat__Policy_Corporate L3, 31)
#
#    inc_set 1 - XGBRegressor(base_score=None, booster=None, callbacks=None,\n             colsample_bylevel=None, colsample_bynode=None,\n             colsample_bytree=None, device=None, early_stopping_rounds=None,\n             enable_categorical=False, eval_metric=None, feature_types=None,\n             gamma=None, grow_policy=None, importance_type=None,\n             interaction_constraints=None, learning_rate=None, max_bin=None,\n             max_cat_threshold=None, max_cat_to_onehot=None,\n             max_delta_step=None, max_depth=None, max_leaves=None,\n             min_child_weight=None, missing=nan, monotone_constraints=None,\n             multi_strategy=None, n_estimators=None, n_jobs=None,\n             num_parallel_tree=None, random_state=None, ...) - 71.47602603998926 - 0.038780969920706225  \
# 0                   (num__Months Since Last Claim, 1)
# 1             (num__Months Since Policy Inception, 1)
# 2                        (num__Total Claim Amount, 1)
# 3                               (cat__Response_No, 1)
# 4                            (cat__Coverage_Basic, 1)
# 5                         (cat__Coverage_Extended, 1)
# 6                          (cat__Coverage_Premium, 1)
# 7                 (cat__EmploymentStatus_Employed, 1)
# 8               (cat__EmploymentStatus_Unemployed, 1)
# 9                       (cat__Location Code_Rural, 1)
# 10                   (cat__Location Code_Suburban, 1)
# 11                   (cat__Marital Status_Married, 1)
# 12                    (cat__Marital Status_Single, 1)
# 13                  (cat__Renew Offer Type_Offer3, 1)
# 14              (cat__Vehicle Class_Four-Door Car, 1)
# 15                 (cat__Vehicle Class_Luxury Car, 1)
# 16                 (cat__Vehicle Class_Luxury SUV, 1)
# 17                        (cat__Vehicle Class_SUV, 1)
# 18                 (cat__Vehicle Class_Sports Car, 1)
# 19               (cat__Vehicle Class_Two-Door Car, 1)
# 20                         (cat__Education_Doctor, 2)
# 21                         (cat__Education_Master, 3)
# 22                     (cat__Sales Channel_Branch, 4)
# 23                        (cat__Sales Channel_Web, 5)
# 24                 (cat__EmploymentStatus_Retired, 6)
# 25                         (cat__State_Washington, 7)
# 26                  (cat__Marital Status_Divorced, 8)
# 27                       (cat__Policy_Personal L2, 9)
# 28                       (cat__Education_College, 10)
# 29                           (cat__State_Arizona, 11)
# 30                     (cat__Policy_Corporate L1, 12)
# 31               (cat__Sales Channel_Call Center, 13)
# 32                     (cat__Sales Channel_Agent, 14)
# 33                      (cat__Vehicle Size_Small, 15)
# 34                      (cat__Vehicle Size_Large, 16)
# 35                     (cat__Policy_Corporate L3, 17)
# 36               (num__Number of Open Complaints, 18)
# 37                       (cat__Policy_Special L2, 19)
# 38                                (cat__Gender_F, 20)
# 39                      (cat__Policy_Personal L1, 21)
# 40          (cat__Education_High School or Below, 22)
# 41                     (cat__Location Code_Urban, 23)
# 42                (cat__Policy Type_Special Auto, 24)
# 43                 (cat__Renew Offer Type_Offer1, 25)
# 44                 (cat__Renew Offer Type_Offer2, 26)
# 45                        (cat__State_California, 27)
# ...
# 30                                (cat__Gender_F, 12)
# 31                (cat__Vehicle Class_Luxury SUV, 13)
# 32                    (cat__Vehicle Size_Medsize, 14)
# 33                        (cat__State_Washington, 15)
# 34                     (cat__Location Code_Urban, 16)
# 35                      (cat__Policy_Personal L3, 17)
# 36                     (cat__Sales Channel_Agent, 18)
# 37                 (cat__Renew Offer Type_Offer4, 19)
# 38                            (cat__State_Oregon, 20)
# 39                       (cat__Sales Channel_Web, 21)
# 40                  (cat__Marital Status_Married, 22)
# 41                           (cat__State_Arizona, 23)
# 42                      (cat__Education_Bachelor, 24)
# 43                       (cat__Policy_Special L2, 25)
# 44               (cat__EmploymentStatus_Employed, 26)
# 45                      (cat__Policy_Personal L1, 27)
# 46                     (cat__Policy_Corporate L3, 28)
# 47                             (cat__Response_No, 29)
# 48                     (cat__Policy_Corporate L2, 30)
# 49              (cat__Policy Type_Corporate Auto, 31)

# %% [markdown]
# ### Use a voting mechanism to determine most important targetable feature values to get highest CLV

# %% [markdown]
# - Add weights (increase in frequency) to features from subsets with higher average CLV
# - Get the most frequent values for targetable features that are important

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
# Create a list of the targetable features
targetable = ["State", "Education", "EmploymentStatus", 
              "Gender", "Income", "Location Code", "Marital Status", 
              "Vehicle Class", "Vehicle Size"]

# %%
# For each value of each targetable feature, record how many times they appear in feature importance table
mpa_imp_feats_top20 = mpa_imp_feats.head(20)

melted_mpa = mpa_imp_feats_top20.melt(var_name='Feature', value_name='Value')

value_counts = melted_mpa['Value'].value_counts().reset_index()
value_counts.columns = ['Value', 'Count']

print(value_counts)
# Out:
#                                        Value  Count
# 0               (num__Total Claim Amount, 1)     25
# 1                 (cat__Coverage_Premium, 1)     25
# 2         (cat__Vehicle Class_Sports Car, 1)     25
# 3                (cat__Vehicle Class_SUV, 1)     25
# 4                   (cat__Coverage_Basic, 1)     25
# 5         (cat__Vehicle Class_Luxury Car, 1)     25
# 6      (cat__Vehicle Class_Four-Door Car, 1)     25
# 7         (cat__Vehicle Class_Luxury SUV, 1)     24
# 8                (cat__Coverage_Extended, 1)     23
# 9       (cat__Vehicle Class_Two-Door Car, 1)     18
# 10          (cat__Location Code_Suburban, 1)     18
# 11     (cat__EmploymentStatus_Unemployed, 1)     14
# 12       (cat__EmploymentStatus_Employed, 1)     13
# 13   (num__Months Since Policy Inception, 1)     12
# 14          (cat__Marital Status_Married, 1)     11
# 15                     (cat__Response_No, 1)     11
# 16             (cat__Location Code_Rural, 1)     11
# 17         (num__Months Since Last Claim, 1)     11
# 18           (cat__Marital Status_Single, 1)     10
# 19            (cat__Sales Channel_Branch, 1)      9
# 20                (cat__Education_Doctor, 1)      9
# 21         (cat__Renew Offer Type_Offer1, 1)      8
# 22              (cat__Policy_Personal L1, 1)      8
# 23         (cat__Renew Offer Type_Offer3, 1)      7
# 24        (cat__Policy Type_Special Auto, 1)      7
# 25              (cat__Policy_Personal L2, 1)      6
# 26                (cat__Education_Master, 1)      6
# 27                   (cat__State_Arizona, 1)      6
# 28       (cat__Sales Channel_Call Center, 1)      6
# 29               (cat__Sales Channel_Web, 1)      6
# 30               (cat__Policy_Special L2, 1)      6
# 31               (cat__Policy_Special L1, 1)      5
# 32       (num__Number of Open Complaints, 1)      5
# 33               (cat__Education_College, 1)      5
# 34             (cat__Policy_Corporate L1, 1)      5
# 35               (cat__Policy_Special L3, 1)      5
# 36  (cat__Education_High School or Below, 1)      5
# 37         (cat__Renew Offer Type_Offer2, 1)      5
# 38             (cat__Location Code_Urban, 1)      5
# 39                        (cat__Gender_F, 1)      5
# 40                (cat__State_Washington, 1)      4
# 41                (cat__State_California, 1)      4
# 42      (cat__Policy Type_Corporate Auto, 1)      4
# 43             (cat__Sales Channel_Agent, 1)      4
# 44              (cat__Vehicle Size_Large, 1)      4
# 45                        (cat__Gender_M, 1)      4
# 46                    (cat__State_Oregon, 1)      4
# 47        (cat__EmploymentStatus_Retired, 1)      4
# 48              (cat__Policy_Personal L3, 1)      3
# 49  (cat__EmploymentStatus_Medical Leave, 1)      3
# 50         (cat__Renew Offer Type_Offer4, 1)      3
# 51              (cat__Education_Bachelor, 1)      3
# 52       (cat__EmploymentStatus_Disabled, 1)      3
# 53                    (cat__State_Nevada, 1)      3
# 54             (cat__Policy_Corporate L3, 1)      2
# 55            (cat__Vehicle Size_Medsize, 1)      2
# 56              (cat__Vehicle Size_Small, 1)      2
# 57                    (cat__Response_Yes, 1)      1
# 58             (cat__Policy_Corporate L2, 1)      1
# 59         (cat__Marital Status_Divorced, 1)      1
# 60       (cat__Policy Type_Personal Auto, 1)      1
