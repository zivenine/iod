# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

pd.set_option('display.max_columns', None)

# %% [markdown]
# **Data Dictionary**
#
# ID : Unique Customer ID
#
# Gender : Gender of the applicant
#
# DOB : Date of Birth of the applicant
#
# Lead_Creation_Date : Date on which Lead was created
#
# City_Code : Anonymised Code for the City
#
# City_Category: Anonymised City Feature
#
# Employer_Code: Anonymised Code for the Employer
#
# Employer_Category1 : Anonymised Employer Feature
#
# Employer_Category2: Anonymised Employer Feature
#
# Monthly_Income : Monthly Income in Dollars
#
# Customer_Existing_Primary_Bank_Code : Anonymised Customer Bank Code
#
# Primary_Bank_Type: Anonymised Bank Feature
#
# Contacted: Contact Verified (Y/N)
#
# Source : Categorical Variable representing source of lead
#
# Source_Category: Type of Source
#
# Existing_EMI : EMI of Existing Loans in Dollars
#
# Loan_Amount: Loan Amount Requested
#
# Loan_Period: Loan Period (Years)
#
# Interest_Rate: Interest Rate of Submitted Loan Amount
#
# EMI: EMI of Requested Loan Amount in dollars
#
# Var1: Anonymized Categorical variable with multiple levels
#
# Approved: (Target) Whether a loan is Approved or not (1-0) . Customer is Qualified Lead or not (1-0)

# %%
leads = pd.read_csv("bank_loan_leads/train_loan/train.csv")

# %%
leads.head()
# Out:
#                 ID  Gender       DOB Lead_Creation_Date City_Code  \
# 0  APPC90493171225  Female  23/07/79           15/07/16    C10001
# 1  APPD40611263344    Male  07/12/86           04/07/16    C10003
# 2  APPE70289249423    Male  10/12/82           19/07/16    C10125
# 3  APPF80273865537    Male  30/01/89           09/07/16    C10477
# 4  APPG60994436641    Male  19/04/85           20/07/16    C10002
#
#   City_Category Employer_Code Employer_Category1  Employer_Category2  \
# 0             A    COM0044082                  A                 4.0
# 1             A    COM0000002                  C                 1.0
# 2             C    COM0005267                  C                 4.0
# 3             C    COM0004143                  A                 4.0
# 4             A    COM0001781                  A                 4.0
#
#    Monthly_Income Customer_Existing_Primary_Bank_Code Primary_Bank_Type  \
# 0          2000.0                                B001                 P
# 1          3500.0                                B002                 P
# 2          2250.0                                B003                 G
# 3          3500.0                                B003                 G
# 4         10000.0                                B001                 P
#
#   Contacted Source Source_Category  Existing_EMI  Loan_Amount  Loan_Period  \
# 0         N   S122               G           0.0          NaN          NaN
# 1         Y   S122               G           0.0      20000.0          2.0
# 2         Y   S143               B           0.0      45000.0          4.0
# 3         Y   S143               B           0.0      92000.0          5.0
# 4         Y   S134               B        2500.0      50000.0          2.0
#
#    Interest_Rate    EMI  Var1  Approved
# 0            NaN    NaN     0         0
# 1          13.25  953.0    10         0
# 2            NaN    NaN     0         0
# 3            NaN    NaN     7         0
# 4            NaN    NaN    10         0

# %%
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69713 entries, 0 to 69712
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   69713 non-null  object
#  1   Gender                               69713 non-null  object
#  2   DOB                                  69698 non-null  object
#  3   Lead_Creation_Date                   69713 non-null  object
#  4   City_Code                            68899 non-null  object
#  5   City_Category                        68899 non-null  object
#  6   Employer_Code                        65695 non-null  object
#  7   Employer_Category1                   65695 non-null  object
#  8   Employer_Category2                   65415 non-null  float64
#  9   Monthly_Income                       69713 non-null  float64
#  10  Customer_Existing_Primary_Bank_Code  60322 non-null  object
#  11  Primary_Bank_Type                    60322 non-null  object
#  12  Contacted                            69713 non-null  object
#  13  Source                               69713 non-null  object
#  14  Source_Category                      69713 non-null  object
#  15  Existing_EMI                         69662 non-null  float64
#  16  Loan_Amount                          42004 non-null  float64
#  17  Loan_Period                          42004 non-null  float64
#  18  Interest_Rate                        22276 non-null  float64
#  19  EMI                                  22276 non-null  float64
#  20  Var1                                 69713 non-null  int64
#  21  Approved                             69713 non-null  int64
# dtypes: float64(7), int64(2), object(13)
# memory usage: 11.7+ MB

# %%
leads.describe().T
# Out:
#                       count          mean            std      min       25%  \
# Employer_Category2  65415.0      3.720187       0.807374     1.00      4.00
# Monthly_Income      69713.0   5622.283200  174767.061840     0.00   1650.00
# Existing_EMI        69662.0    360.928751    2288.517927     0.00      0.00
# Loan_Amount         42004.0  39429.982859   30727.595990  5000.00  20000.00
# Loan_Period         42004.0      3.890629       1.167491     1.00      3.00
# Interest_Rate       22276.0     19.213570       5.847136    11.99     15.25
# EMI                 22276.0   1101.466242     752.661394   118.00    649.00
# Var1                69713.0      3.948446       3.819214     0.00      0.00
# Approved            69713.0      0.014631       0.120073     0.00      0.00
#
#                         50%      75%         max
# Employer_Category2      4.0      4.0         4.0
# Monthly_Income       2500.0   4000.0  38383838.3
# Existing_EMI            0.0    350.0    545436.5
# Loan_Amount         30000.0  50000.0    300000.0
# Loan_Period             4.0      5.0         6.0
# Interest_Rate          18.0     20.0        37.0
# EMI                   941.0   1295.0     13556.0
# Var1                    2.0      7.0        10.0
# Approved                0.0      0.0         1.0

# %%
# sns.displot(leads, x="Monthly_Income")
# plt.xscale('log')
# plt.title(f"Histogram of Monthly Income")
# plt.show()

# %%
# def draw_hists(data, columns):
#     for column in columns:
#         sns.displot(data, x=column)
#         plt.title(f"Histogram of {column}")
#         plt.show()
# cols = leads.columns
# draw_hists(leads, cols)

# %%
# sns.pairplot with Approved as hue could be interesting

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Handle missing values

# %%
leads.isnull().sum()
# Out:
# ID                                         0
# Gender                                     0
# DOB                                       15
# Lead_Creation_Date                         0
# City_Code                                814
# City_Category                            814
# Employer_Code                           4018
# Employer_Category1                      4018
# Employer_Category2                      4298
# Monthly_Income                             0
# Customer_Existing_Primary_Bank_Code     9391
# Primary_Bank_Type                       9391
# Contacted                                  0
# Source                                     0
# Source_Category                            0
# Existing_EMI                              51
# Loan_Amount                            27709
# Loan_Period                            27709
# Interest_Rate                          47437
# EMI                                    47437
# Var1                                       0
# Approved                                   0
# dtype: int64

# %% [markdown]
# ### For each column, check how many of the observations with missing values were Approved for a loan

# %%
def check_missing_approved(data):
    cols_missing = [col for col in data.columns if data[col].isnull().any()]
    missing_cols_approved = []
    total_missing = []
    vals = []
    percent_missing = []
    for col in cols_missing:
        approved_count = data[data[col].isnull() & (data['Approved'] == 1)].shape[0]
        missing_cols_approved.append(approved_count)
        total_missing_count = data[col].isnull().sum()
        total_missing.append(total_missing_count)
        val_count = data[col].nunique()
        vals.append(val_count)
        pct = np.round((total_missing_count/data[col].shape[0])*100,2)
        percent_missing.append(pct)

    result_table = pd.DataFrame({
        'Column with Missing Data': cols_missing,
        'No. of Unique Values': vals,
        'Total Missing': total_missing,
        'Percentage Missing': percent_missing,
        'Approved Count': missing_cols_approved
        
    })

    return result_table

check_missing_approved(leads)
# Out:
#                Column with Missing Data  No. of Unique Values  Total Missing  \
# 0                                   DOB                 10759             15
# 1                             City_Code                   678            814
# 2                         City_Category                     3            814
# 3                         Employer_Code                 36617           4018
# 4                    Employer_Category1                     3           4018
# 5                    Employer_Category2                     4           4298
# 6   Customer_Existing_Primary_Bank_Code                    57           9391
# 7                     Primary_Bank_Type                     2           9391
# 8                          Existing_EMI                  3245             51
# 9                           Loan_Amount                   196          27709
# 10                          Loan_Period                     6          27709
# 11                        Interest_Rate                    72          47437
# 12                                  EMI                  2179          47437
#
#     Percentage Missing  Approved Count
# 0                 0.02               0
# 1                 1.17               2
# 2                 1.17               2
# 3                 5.76               5
# 4                 5.76               5
# 5                 6.17              13
# 6                13.47              20
# 7                13.47              20
# 8                 0.07               1
# 9                39.75             175
# 10               39.75             175
# 11               68.05             533
# 12               68.05             533

# %% [markdown]
# Given that there are so few observations in which Approved==1, this will help us decide if we can afford to delete rows with missing values.
#
# **DOB** - drop rows with missing
#
# **City_Code** - the rows with City_Code missing have almost all other features missing too and only two are Approved. We can drop these rows
#
# **City_Category** - the missing values will be handled when we delete rows with missing City_Code
#
# **Employer_Code** - drop column, too many categories to be of use
#
# **Empoloyer_Category1** - impute with mode
#
# **Employer_Category2** - impute with mode
#
# **Customer_Existing_Primary_Bank_Code** - we can impute with mode, but I don't think this feature will render much value
#
# **Primary_Bank_Type** - impute with mode
#
# **Existing_EMI** - impute with mean, or drop rows
#
# **Loan_Amount** - check distribution, if skewed use median, else mean
#
# **Loan_Period** - impute with median if skewed, else use mean
#
# **Interest_Rate** - impute with mean
#
# **EMI** - infer from Loan_Amount, Interest_Rate, and Loan_Period

# %% [markdown]
# ### Drop ID and Employer_Code from the table

# %%
leads_1 = leads.drop(['ID', 'Employer_Code'], axis=1)

# %% [markdown]
# ### Drop missing value rows from DOB

# %%
missing_dob = leads[leads['DOB'].isnull()].index
leads_2 = leads_1.drop(missing_dob, axis=0)

# %% [markdown]
# ### Impute mean into Interest_Rate

# %%
interest_rate_mean = leads['Interest_Rate'].mean()
leads_2['Interest_Rate'].fillna(interest_rate_mean, inplace=True)

# %% [markdown]
# ### Impute median values into Loan_Amount and Loan_Period

# %%
def impute_median(data, cols):
    for col in cols:
        col_median = data[col].median()
        data[col].fillna(col_median, inplace=True,)
    return data

cols = ['Loan_Amount', 'Loan_Period']
leads_3 = impute_median(leads_2, cols)

# %%
leads_3.isnull().sum()
# Out:
# Gender                                     0
# DOB                                        0
# Lead_Creation_Date                         0
# City_Code                                814
# City_Category                            814
# Employer_Category1                      4003
# Employer_Category2                      4283
# Monthly_Income                             0
# Customer_Existing_Primary_Bank_Code     9376
# Primary_Bank_Type                       9376
# Contacted                                  0
# Source                                     0
# Source_Category                            0
# Existing_EMI                              51
# Loan_Amount                                0
# Loan_Period                                0
# Interest_Rate                              0
# EMI                                    47422
# Var1                                       0
# Approved                                   0
# dtype: int64

# %% [markdown]
# ###

# %% [markdown]
# ### Impute mode for Employer_Category1, Employer_Category2, Customer_Existing_Primary_Bank_Code, and Primary_Bank_Type

# %%
def impute_mode(data, cols):
    for col in cols:
        col_mode = data[col].mode()[0]
        data[col].fillna(col_mode, inplace=True,)
    return data

cols = ['Employer_Category1', 'Employer_Category2', 'Customer_Existing_Primary_Bank_Code', 'Primary_Bank_Type']
leads_4 = impute_mode(leads_3, cols)

# %%
leads_4.isnull().sum()
# Out:
# Gender                                     0
# DOB                                        0
# Lead_Creation_Date                         0
# City_Code                                814
# City_Category                            814
# Employer_Category1                         0
# Employer_Category2                         0
# Monthly_Income                             0
# Customer_Existing_Primary_Bank_Code        0
# Primary_Bank_Type                          0
# Contacted                                  0
# Source                                     0
# Source_Category                            0
# Existing_EMI                              51
# Loan_Amount                                0
# Loan_Period                                0
# Interest_Rate                              0
# EMI                                    47422
# Var1                                       0
# Approved                                   0
# dtype: int64

# %% [markdown]
# ### Drop rows with missing values in City_Code

# %%
missing_city_code = leads[leads['City_Code'].isnull()].index
leads_5 = leads_4.drop(missing_city_code, axis=0)

# %%
leads_5.isnull().sum()
# Out:
# Gender                                     0
# DOB                                        0
# Lead_Creation_Date                         0
# City_Code                                  0
# City_Category                              0
# Employer_Category1                         0
# Employer_Category2                         0
# Monthly_Income                             0
# Customer_Existing_Primary_Bank_Code        0
# Primary_Bank_Type                          0
# Contacted                                  0
# Source                                     0
# Source_Category                            0
# Existing_EMI                              51
# Loan_Amount                                0
# Loan_Period                                0
# Interest_Rate                              0
# EMI                                    46608
# Var1                                       0
# Approved                                   0
# dtype: int64

# %%
leads_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68884 entries, 0 to 69712
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               68884 non-null  object
#  1   DOB                                  68884 non-null  object
#  2   Lead_Creation_Date                   68884 non-null  object
#  3   City_Code                            68884 non-null  object
#  4   City_Category                        68884 non-null  object
#  5   Employer_Category1                   68884 non-null  object
#  6   Employer_Category2                   68884 non-null  float64
#  7   Monthly_Income                       68884 non-null  float64
#  8   Customer_Existing_Primary_Bank_Code  68884 non-null  object
#  9   Primary_Bank_Type                    68884 non-null  object
#  10  Contacted                            68884 non-null  object
#  11  Source                               68884 non-null  object
#  12  Source_Category                      68884 non-null  object
#  13  Existing_EMI                         68833 non-null  float64
#  14  Loan_Amount                          68884 non-null  float64
#  15  Loan_Period                          68884 non-null  float64
#  16  Interest_Rate                        68884 non-null  float64
#  17  EMI                                  22276 non-null  float64
#  18  Var1                                 68884 non-null  int64
#  19  Approved                             68884 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 11.0+ MB

# %% [markdown]
# ### Impute missing Existing_EMI with mean

# %%
leads_6 = leads_5.copy()
emi_mean = leads_6['Existing_EMI'].mean()
leads_6['Existing_EMI'].fillna(emi_mean, inplace=True)

# %%
leads_6.isnull().sum()
# Out:
# Gender                                     0
# DOB                                        0
# Lead_Creation_Date                         0
# City_Code                                  0
# City_Category                              0
# Employer_Category1                         0
# Employer_Category2                         0
# Monthly_Income                             0
# Customer_Existing_Primary_Bank_Code        0
# Primary_Bank_Type                          0
# Contacted                                  0
# Source                                     0
# Source_Category                            0
# Existing_EMI                               0
# Loan_Amount                                0
# Loan_Period                                0
# Interest_Rate                              0
# EMI                                    46608
# Var1                                       0
# Approved                                   0
# dtype: int64

# %%
leads_6.head()
# Out:
#    Gender       DOB Lead_Creation_Date City_Code City_Category  \
# 0  Female  23/07/79           15/07/16    C10001             A
# 1    Male  07/12/86           04/07/16    C10003             A
# 2    Male  10/12/82           19/07/16    C10125             C
# 3    Male  30/01/89           09/07/16    C10477             C
# 4    Male  19/04/85           20/07/16    C10002             A
#
#   Employer_Category1  Employer_Category2  Monthly_Income  \
# 0                  A                 4.0          2000.0
# 1                  C                 1.0          3500.0
# 2                  C                 4.0          2250.0
# 3                  A                 4.0          3500.0
# 4                  A                 4.0         10000.0
#
#   Customer_Existing_Primary_Bank_Code Primary_Bank_Type Contacted Source  \
# 0                                B001                 P         N   S122
# 1                                B002                 P         Y   S122
# 2                                B003                 G         Y   S143
# 3                                B003                 G         Y   S143
# 4                                B001                 P         Y   S134
#
#   Source_Category  Existing_EMI  Loan_Amount  Loan_Period  Interest_Rate  \
# 0               G           0.0      30000.0          4.0       19.21357
# 1               G           0.0      20000.0          2.0       13.25000
# 2               B           0.0      45000.0          4.0       19.21357
# 3               B           0.0      92000.0          5.0       19.21357
# 4               B        2500.0      50000.0          2.0       19.21357
#
#      EMI  Var1  Approved
# 0    NaN     0         0
# 1  953.0    10         0
# 2    NaN     0         0
# 3    NaN     7         0
# 4    NaN    10         0

# %% [markdown]
# ### Infer EMI from Loan_Amount, Interest_Rate and Loan_Period

# %%
def emi_calc(data):
    for i, row in data.iterrows():
        if pd.isnull(row['EMI']):
            monthly_interest_rate = row['Interest_Rate'] / 100 / 12
            total_payments = row['Loan_Period'] * 12
            calc_emi = row['Loan_Amount'] * monthly_interest_rate * (1 + monthly_interest_rate)**total_payments / ((1 + monthly_interest_rate)**total_payments-1)
            data.at[i, 'EMI'] = calc_emi
    return data

leads_61 = emi_calc(leads_6)

# %%
leads_61.isnull().sum()
# Out:
# Gender                                 0
# DOB                                    0
# Lead_Creation_Date                     0
# City_Code                              0
# City_Category                          0
# Employer_Category1                     0
# Employer_Category2                     0
# Monthly_Income                         0
# Customer_Existing_Primary_Bank_Code    0
# Primary_Bank_Type                      0
# Contacted                              0
# Source                                 0
# Source_Category                        0
# Existing_EMI                           0
# Loan_Amount                            0
# Loan_Period                            0
# Interest_Rate                          0
# EMI                                    0
# Var1                                   0
# Approved                               0
# dtype: int64

# %% [markdown]
# # Fix datatypes

# %%
leads_61.head(5)
# Out:
#    Gender       DOB Lead_Creation_Date City_Code City_Category  \
# 0  Female  23/07/79           15/07/16    C10001             A
# 1    Male  07/12/86           04/07/16    C10003             A
# 2    Male  10/12/82           19/07/16    C10125             C
# 3    Male  30/01/89           09/07/16    C10477             C
# 4    Male  19/04/85           20/07/16    C10002             A
#
#   Employer_Category1  Employer_Category2  Monthly_Income  \
# 0                  A                 4.0          2000.0
# 1                  C                 1.0          3500.0
# 2                  C                 4.0          2250.0
# 3                  A                 4.0          3500.0
# 4                  A                 4.0         10000.0
#
#   Customer_Existing_Primary_Bank_Code Primary_Bank_Type Contacted Source  \
# 0                                B001                 P         N   S122
# 1                                B002                 P         Y   S122
# 2                                B003                 G         Y   S143
# 3                                B003                 G         Y   S143
# 4                                B001                 P         Y   S134
#
#   Source_Category  Existing_EMI  Loan_Amount  Loan_Period  Interest_Rate  \
# 0               G           0.0      30000.0          4.0       19.21357
# 1               G           0.0      20000.0          2.0       13.25000
# 2               B           0.0      45000.0          4.0       19.21357
# 3               B           0.0      92000.0          5.0       19.21357
# 4               B        2500.0      50000.0          2.0       19.21357
#
#            EMI  Var1  Approved
# 0   900.387994     0         0
# 1   953.000000    10         0
# 2  1350.581991     0         0
# 3  2397.355046     7         0
# 4  2525.622064    10         0

# %%
leads_61.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68884 entries, 0 to 69712
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               68884 non-null  object
#  1   DOB                                  68884 non-null  object
#  2   Lead_Creation_Date                   68884 non-null  object
#  3   City_Code                            68884 non-null  object
#  4   City_Category                        68884 non-null  object
#  5   Employer_Category1                   68884 non-null  object
#  6   Employer_Category2                   68884 non-null  float64
#  7   Monthly_Income                       68884 non-null  float64
#  8   Customer_Existing_Primary_Bank_Code  68884 non-null  object
#  9   Primary_Bank_Type                    68884 non-null  object
#  10  Contacted                            68884 non-null  object
#  11  Source                               68884 non-null  object
#  12  Source_Category                      68884 non-null  object
#  13  Existing_EMI                         68884 non-null  float64
#  14  Loan_Amount                          68884 non-null  float64
#  15  Loan_Period                          68884 non-null  float64
#  16  Interest_Rate                        68884 non-null  float64
#  17  EMI                                  68884 non-null  float64
#  18  Var1                                 68884 non-null  int64
#  19  Approved                             68884 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 13.1+ MB

# %%
# Check each column for multiple datatypes: 
def check_dtypes_per_col(data):
    for col in data:
        unique_dtypes = data[col].apply(type).unique()
        print(f"{col} datatypes: ", unique_dtypes)

check_dtypes_per_col(leads_61)
# Out:
# Gender datatypes:  [<class 'str'>]
# DOB datatypes:  [<class 'str'>]
# Lead_Creation_Date datatypes:  [<class 'str'>]
# City_Code datatypes:  [<class 'str'>]
# City_Category datatypes:  [<class 'str'>]
# Employer_Category1 datatypes:  [<class 'str'>]
# Employer_Category2 datatypes:  [<class 'float'>]
# Monthly_Income datatypes:  [<class 'float'>]
# Customer_Existing_Primary_Bank_Code datatypes:  [<class 'str'>]
# Primary_Bank_Type datatypes:  [<class 'str'>]
# Contacted datatypes:  [<class 'str'>]
# Source datatypes:  [<class 'str'>]
# Source_Category datatypes:  [<class 'str'>]
# Existing_EMI datatypes:  [<class 'float'>]
# Loan_Amount datatypes:  [<class 'float'>]
# Loan_Period datatypes:  [<class 'float'>]
# Interest_Rate datatypes:  [<class 'float'>]
# EMI datatypes:  [<class 'float'>]
# Var1 datatypes:  [<class 'int'>]
# Approved datatypes:  [<class 'int'>]

# %%
leads_7 = leads_61.copy()
leads_7['DOB'] = pd.to_datetime(leads_7['DOB'], format="%d/%m/%y")

# %%
leads_7['Lead_Creation_Date'] = pd.to_datetime(leads_7['Lead_Creation_Date'], format="%d/%m/%y")

# %%
leads_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68884 entries, 0 to 69712
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               68884 non-null  object
#  1   DOB                                  68884 non-null  datetime64[ns]
#  2   Lead_Creation_Date                   68884 non-null  datetime64[ns]
#  3   City_Code                            68884 non-null  object
#  4   City_Category                        68884 non-null  object
#  5   Employer_Category1                   68884 non-null  object
#  6   Employer_Category2                   68884 non-null  float64
#  7   Monthly_Income                       68884 non-null  float64
#  8   Customer_Existing_Primary_Bank_Code  68884 non-null  object
#  9   Primary_Bank_Type                    68884 non-null  object
#  10  Contacted                            68884 non-null  object
#  11  Source                               68884 non-null  object
#  12  Source_Category                      68884 non-null  object
#  13  Existing_EMI                         68884 non-null  float64
#  14  Loan_Amount                          68884 non-null  float64
#  15  Loan_Period                          68884 non-null  float64
#  16  Interest_Rate                        68884 non-null  float64
#  17  EMI                                  68884 non-null  float64
#  18  Var1                                 68884 non-null  int64
#  19  Approved                             68884 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(2), object(9)
# memory usage: 13.1+ MB

# %% [markdown]
# # Handle anomalies and outliers

# %%
# Monthly_Income and Existing_EMI have outliers that look like they have been entered incorrectly.

# %%
leads_7.describe()
# Out:
#                                  DOB             Lead_Creation_Date  \
# count                          68884                          68884
# mean   1989-07-26 14:30:13.274490624  2016-08-17 12:46:48.338656512
# min              1969-01-01 00:00:00            2016-07-01 00:00:00
# 25%              1983-10-07 00:00:00            2016-07-25 00:00:00
# 50%              1987-11-10 00:00:00            2016-08-19 00:00:00
# 75%              1991-01-27 00:00:00            2016-09-09 00:00:00
# max              2068-12-28 00:00:00            2016-09-30 00:00:00
# std                              NaN                            NaN
#
#        Employer_Category2  Monthly_Income   Existing_EMI    Loan_Amount  \
# count        68884.000000    6.888400e+04   68884.000000   68884.000000
# mean             3.735831    5.644442e+03     359.211154   35750.203240
# min              1.000000    0.000000e+00       0.000000    5000.000000
# 25%              4.000000    1.648600e+03       0.000000   29000.000000
# 50%              4.000000    2.500000e+03       0.000000   30000.000000
# 75%              4.000000    4.000000e+03     350.000000   36000.000000
# max              4.000000    3.838384e+07  545436.500000  300000.000000
# std              0.787018    1.758148e+05    2297.518854   24431.506112
#
#         Loan_Period  Interest_Rate           EMI          Var1      Approved
# count  68884.000000   68884.000000  68884.000000  68884.000000  68884.000000
# mean       3.933308      19.213570   1084.709868      3.995964      0.014778
# min        1.000000      11.990000    118.000000      0.000000      0.000000
# 25%        4.000000      19.213570    900.387994      0.000000      0.000000
# 50%        4.000000      19.213570    900.387994      2.000000      0.000000
# 75%        4.000000      19.213570   1102.922701      7.000000      0.000000
# max        6.000000      37.000000  13838.780470     10.000000      1.000000
# std        0.913230       3.325033    677.770050      3.817336      0.120666

# %%
leads_7.sort_values(by=["Existing_EMI"], axis=0, ascending=False)
# Out:
#        Gender        DOB Lead_Creation_Date City_Code City_Category  \
# 20442    Male 1976-05-13         2016-07-29    C10001             A
# 38031    Male 1986-04-04         2016-08-23    C10001             A
# 14828  Female 1983-01-21         2016-07-22    C10002             A
# 14827  Female 1983-01-21         2016-07-22    C10002             A
# 26628  Female 1973-03-30         2016-08-08    C10001             A
# ...       ...        ...                ...       ...           ...
# 27901    Male 1990-10-04         2016-08-09    C10010             A
# 27903    Male 2063-06-10         2016-08-09    C10007             A
# 27904    Male 1991-11-14         2016-08-09    C10004             A
# 27905  Female 1992-09-15         2016-08-09    C10012             A
# 69712    Male 1989-12-31         2016-09-30    C10003             A
#
#       Employer_Category1  Employer_Category2  Monthly_Income  \
# 20442                  A                 4.0      12010013.2
# 38031                  A                 4.0        562626.6
# 14828                  A                 4.0         70000.0
# 14827                  A                 4.0         70000.0
# 26628                  C                 4.0         60000.0
# ...                  ...                 ...             ...
# 27901                  C                 4.0          3800.0
# 27903                  A                 4.0          5000.0
# 27904                  B                 3.0          2500.0
# 27905                  C                 4.0          1000.0
# 69712                  A                 1.0          4230.0
#
#       Customer_Existing_Primary_Bank_Code Primary_Bank_Type Contacted Source  \
# 20442                                B003                 G         Y   S153
# 38031                                B002                 P         Y   S122
# 14828                                B001                 P         N   S133
# 14827                                B001                 P         N   S133
# 26628                                B002                 P         N   S143
# ...                                   ...               ...       ...    ...
# 27901                                B001                 P         Y   S133
# 27903                                B001                 P         Y   S133
# 27904                                B001                 P         Y   S133
# 27905                                B002                 P         N   S133
# 69712                                B001                 P         Y   S122
#
#       Source_Category  Existing_EMI  Loan_Amount  Loan_Period  Interest_Rate  \
# 20442               B      545436.5      50000.0          5.0       15.50000
# 38031               B       62626.6      30000.0          2.0       15.25000
# 14828               B       42000.0      30000.0          4.0       19.21357
# 14827               B       42000.0      30000.0          4.0       19.21357
# 26628               B       30000.0      30000.0          4.0       19.21357
# ...               ...           ...          ...          ...            ...
# 27901               B           0.0      20000.0          2.0       19.21357
# 27903               B           0.0      20000.0          5.0       19.21357
# 27904               C           0.0      43000.0          5.0       19.21357
# 27905               B           0.0      30000.0          4.0       19.21357
# 69712               G           0.0      69000.0          4.0       13.99000
#
#                EMI  Var1  Approved
# 20442  1203.000000    10         0
# 38031  1458.000000    10         0
# 14828   900.387994     0         0
# 14827   900.387994     0         0
# 26628   900.387994     0         1
# ...            ...   ...       ...
# 27901  1010.248826    10         0
# 27903   521.164140    10         0
# 27904  1120.502902     4         0
# 27905   900.387994     0         0
# 69712  1885.000000    10         0
#
# [68884 rows x 20 columns]

# %%
leads_8 = leads_7.drop([20442, 38031], axis=0)

# %%
quantiles = leads_8['Monthly_Income'].quantile([0.25, 0.5, 0.75])
print(quantiles)
# Out:
# 0.25    1648.2
# 0.50    2500.0
# 0.75    4000.0
# Name: Monthly_Income, dtype: float64

# %%
over_100 = leads_8[leads_8['Monthly_Income'] > 100000]

# %%
leads_9 = leads_8[leads_8['Monthly_Income'] < 100000]

# %%
def get_years(data):
    years = []
    for date in data:
        y = str(date)[:4]
        years.append(y)
    return years 

ys = get_years(leads_9['DOB'])

leads_9['Year'] = ys

leads_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68797 entries, 0 to 69712
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               68797 non-null  object
#  1   DOB                                  68797 non-null  datetime64[ns]
#  2   Lead_Creation_Date                   68797 non-null  datetime64[ns]
#  3   City_Code                            68797 non-null  object
#  4   City_Category                        68797 non-null  object
#  5   Employer_Category1                   68797 non-null  object
#  6   Employer_Category2                   68797 non-null  float64
#  7   Monthly_Income                       68797 non-null  float64
#  8   Customer_Existing_Primary_Bank_Code  68797 non-null  object
#  9   Primary_Bank_Type                    68797 non-null  object
#  10  Contacted                            68797 non-null  object
#  11  Source                               68797 non-null  object
#  12  Source_Category                      68797 non-null  object
#  13  Existing_EMI                         68797 non-null  float64
#  14  Loan_Amount                          68797 non-null  float64
#  15  Loan_Period                          68797 non-null  float64
#  16  Interest_Rate                        68797 non-null  float64
#  17  EMI                                  68797 non-null  float64
#  18  Var1                                 68797 non-null  int64
#  19  Approved                             68797 non-null  int64
#  20  Year                                 68797 non-null  object
# dtypes: datetime64[ns](2), float64(7), int64(2), object(10)
# memory usage: 11.5+ MB
# C:\Users\zive9\AppData\Local\Temp\ipykernel_3064\1662636517.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   leads_9['Year'] = ys

# %%
leads_9['Year'] = pd.to_numeric(leads_9['Year'])

wrong_age = leads_9[leads_9['Year'] > 2000]

wrong_age
# Out:
# C:\Users\zive9\AppData\Local\Temp\ipykernel_3064\3457595887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   leads_9['Year'] = pd.to_numeric(leads_9['Year'])
#        Gender        DOB Lead_Creation_Date City_Code City_Category  \
# 43       Male 2051-07-20         2016-07-01    C10003             A
# 68     Female 2060-12-21         2016-07-01    C10210             C
# 93       Male 2067-05-04         2016-07-01    C10004             A
# 101    Female 2062-11-10         2016-07-01    C10519             C
# 103    Female 2059-03-31         2016-07-01    C10018             C
# ...       ...        ...                ...       ...           ...
# 69651  Female 2067-01-25         2016-09-30    C10002             A
# 69677    Male 2067-10-15         2016-09-30    C10001             A
# 69699    Male 2057-11-01         2016-09-30    C10008             A
# 69700  Female 2064-01-02         2016-09-30    C10078             C
# 69702    Male 2061-03-03         2016-09-30    C10053             B
#
#       Employer_Category1  Employer_Category2  Monthly_Income  \
# 43                     A                 4.0          4500.0
# 68                     A                 4.0         15150.0
# 93                     A                 4.0          6000.0
# 101                    A                 4.0          5000.0
# 103                    A                 4.0          1800.0
# ...                  ...                 ...             ...
# 69651                  A                 4.0          9000.0
# 69677                  A                 4.0          8000.0
# 69699                  C                 4.0          4500.0
# 69700                  A                 4.0          5152.4
# 69702                  A                 4.0          4000.0
#
#       Customer_Existing_Primary_Bank_Code Primary_Bank_Type Contacted Source  \
# 43                                   B002                 P         Y   S133
# 68                                   B032                 G         N   S133
# 93                                   B031                 G         Y   S122
# 101                                  B003                 G         Y   S133
# 103                                  B033                 G         Y   S133
# ...                                   ...               ...       ...    ...
# 69651                                B029                 G         Y   S122
# 69677                                B004                 P         Y   S122
# 69699                                B016                 G         Y   S122
# 69700                                B001                 P         N   S122
# 69702                                B009                 G         Y   S122
#
#       Source_Category  Existing_EMI  Loan_Amount  Loan_Period  Interest_Rate  \
# 43                  B           0.0      94000.0          5.0       19.21357
# 68                  B        3750.0      30000.0          4.0       19.21357
# 93                  B        1700.0      30000.0          3.0       14.85000
# 101                 E         950.7      20000.0          2.0       19.21357
# 103                 C           0.0      40000.0          5.0       20.00000
# ...               ...           ...          ...          ...            ...
# 69651               G           0.0     150000.0          4.0       13.99000
# 69677               G           0.0      10000.0          2.0       14.85000
# 69699               G           0.0      81000.0          4.0       14.85000
# 69700               G        2364.8      30000.0          4.0       19.21357
# 69702               G         845.0      57000.0          4.0       19.21357
#
#                EMI  Var1  Approved  Year
# 43     2449.471460     2         0  2051
# 68      900.387994    10         0  2060
# 93     1038.000000    10         0  2067
# 101    1010.248826     7         0  2062
# 103    1060.000000     2         0  2059
# ...            ...   ...       ...   ...
# 69651  4098.000000     4         0  2067
# 69677   484.000000    10         0  2067
# 69699  2248.000000     4         0  2057
# 69700   900.387994     0         0  2064
# 69702  1710.737188     7         0  2061
#
# [2598 rows x 21 columns]

# %%
# def fix_ages(data):
#     mask = data['Year'] > 2000
#     data.loc[mask, 'Year'] = data.loc[mask, 'Year'] - 100
    
#     fix_ages(leads_9)
    
def fix_ages(data):
    for i, row in data.iterrows():
        if row['Year'] > 2000:
            # Calculate the new year
            new_year = row['Year'] - 100
            # Set the new year value
            data.at[i, 'Year'] = new_year
            
fix_ages(leads_9)

# %%
wrong_age = leads_9[leads_9['Year'] > 2000]

wrong_age
# Out:
# Empty DataFrame
# Columns: [Gender, DOB, Lead_Creation_Date, City_Code, City_Category, Employer_Category1, Employer_Category2, Monthly_Income, Customer_Existing_Primary_Bank_Code, Primary_Bank_Type, Contacted, Source, Source_Category, Existing_EMI, Loan_Amount, Loan_Period, Interest_Rate, EMI, Var1, Approved, Year]
# Index: []

# %%
leads_9.to_csv("Bank Leads Cleaned 20240206v2.csv", index=False)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Create Age feature from DOB

# %%
# dob_dt = pd.to_datetime(leads['DOB'], format="%d/%m/%y")
# leads['DOB'] = dob_dt

# def age(births):
#     current_year = datetime.today().year
#     ages=[]
#     for x in births:
#         birth_year = datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").year
#         ages.append(current_year - birth_year)
#     return ages
# print(age(leads['DOB']))
